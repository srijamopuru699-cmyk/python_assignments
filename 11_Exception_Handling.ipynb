# %% [markdown]
# # Banking Assignment — Exception Handling (100 Questions with Hints)
#
# An unsolved assessment notebook using accounts, deposits, withdrawals, transfers, cards, loans, KYC, fraud monitoring, reconciliation, and audit trails.
#
# **Structure:** 30 easy + 40 medium + 30 difficult = **100 questions**.

# %% [markdown]
# ## Student instructions
#
# Solve all questions using banking scenarios. Practice try/except, custom exceptions, chaining, cleanup, resilient batch processing. Do not store real customer data, credentials, PINs, or complete card numbers. Each question includes a graduated hint but intentionally has no solution.
#
# **Recommended workflow:** write assumptions, implement the smallest correct function/class, test normal and edge cases, then explain your design.

# %% [markdown]
# ---
#
# ## Easy
#
# Fundamentals and direct applications.

# %% [markdown]
# ### Q1. Parse a deposit amount for banking case 1; use sample reference `ACC-1001` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1001"
raw = "1500.50"

try:
    deposit = float(raw)
    print("Account:", account)
    print("Deposit amount:", deposit)

except ValueError:
    print("Invalid deposit amount.")
# Out:
# Account: ACC-1001
# Deposit amount: 1500.5

# %% [markdown]
# ### Q2. Handle a missing account key for banking case 1; use sample reference `ACC-1002` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
accounts = {
    "ACC-1001": 5000.00
}
account_ref = "ACC-1002"
try:
    balance = accounts[account_ref]
    print("Account:", account_ref)
    print("Balance:", balance)
except KeyError:
    print("Account not found.")
# Out:
# Account not found.

# %% [markdown]
# ### Q3. Prevent division by zero in average balance for banking case 1; use sample reference `ACC-1003` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1003"
total_balance = 5000.00
number_of_days = 5
try:
    average_balance = total_balance / number_of_days
    print("Account:", account)
    print("Average balance:", average_balance)
except ZeroDivisionError:
    print("Cannot calculate average balance because the number of days is zero.")
# Out:
# Account: ACC-1003
# Average balance: 1000.0

# %% [markdown]
# ### Q4. Open a transaction file safely for banking case 1; use sample reference `ACC-1004` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1004"
file_name = "transactions.txt"
try:
    file = open(file_name, "r")
    print("Account:", account)
    print("Transaction file opened successfully.")
    file.close()
except FileNotFoundError:
    print("Transaction file not found.")
# Out:
# Transaction file not found.

# %% [markdown]
# ### Q5. Reject a negative withdrawal for banking case 1; use sample reference `ACC-1005` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1005"
balance = 5000.00
withdrawal = -1000.00

try:
    if withdrawal < 0:
        raise ValueError("Withdrawal amount cannot be negative.")

    balance -= withdrawal

    print("Account:", account)
    print("New balance:", balance)

except ValueError as e:
    print("Withdrawal failed:", e)
# Out:
# Withdrawal failed: Withdrawal amount cannot be negative.

# %% [markdown]
# ### Q6. Catch invalid tenure input for banking case 1; use sample reference `ACC-1006` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1006"
tenure_input = "five"

try:
    tenure = int(tenure_input)
    print("Account:", account)
    print("Loan tenure:", tenure, "years")

except ValueError:
    print("Invalid tenure. Tenure must be a whole number.")
# Out:
# Invalid tenure. Tenure must be a whole number.

# %% [markdown]
# ### Q7. Use else after pin-format validation for banking case 1; use sample reference `ACC-1007` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1007"
pin = "1234"

try:
    if len(pin) != 4 or not pin.isdigit():
        raise ValueError("PIN must contain exactly 4 digits.")

except ValueError as e:
    print("PIN validation failed:", e)

else:
    print("Account:", account)
    print("PIN format is valid.")
# Out:
# Account: ACC-1007
# PIN format is valid.

# %% [markdown]
# ### Q8. Use finally to close a session for banking case 1; use sample reference `ACC-1008` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1008"
session = "Banking session"
try:
    print("Account:", account)
    print("Session opened successfully.")
    # Banking operation
    print("Checking account details...")
except Exception as e:
    print("Session error:", e)
finally:
    print("Session closed.")
# Out:
# Account: ACC-1008
# Session opened successfully.
# Checking account details...
# Session closed.

# %% [markdown]
# ### Q9. Catch multiple numeric conversion errors for banking case 1; use sample reference `ACC-1009` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1009"
amount = "abc"
tenure = None

try:
    deposit = float(amount)
    years = int(tenure)

    print("Account:", account)
    print("Deposit:", deposit)
    print("Tenure:", years)

except (ValueError, TypeError):
    print("Invalid numeric input.")
# Out:
# Invalid numeric input.

# %% [markdown]
# ### Q10. Raise a clear valueerror for banking case 1; use sample reference `ACC-1010` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1010"
deposit = -500.00
try:
    if deposit <= 0:
        raise ValueError("Deposit amount must be greater than zero.")
    print("Account:", account)
    print("Deposit:", deposit)
except ValueError as e:
    print("Deposit failed:", e)
# Out:
# Deposit failed: Deposit amount must be greater than zero.

# %% [markdown]
# ### Q11. Parse a deposit amount for banking case 2; use sample reference `ACC-1011` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1011"
raw = "2500.75"
try:
    deposit = float(raw)
    print("Account:", account)
    print("Deposit amount:", deposit)
except ValueError:
    print("Deposit amount must be a valid number.")
# Out:
# Account: ACC-1011
# Deposit amount: 2500.75

# %% [markdown]
# ### Q12. Handle a missing account key for banking case 2; use sample reference `ACC-1012` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1012"
accounts = {
    "ACC-1001": 5000.00,
    "ACC-1002": 7500.00
}
try:
    balance = accounts[account]
    print("Account:", account)
    print("Balance:", balance)
except KeyError:
    print("Account not found.")
# Out:
# Account not found.

# %% [markdown]
# ### Q13. Prevent division by zero in average balance for banking case 2; use sample reference `ACC-1013` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1013"
total_balance = 6000.00
number_of_days = 0
try:
    average_balance = total_balance / number_of_days
    print("Account:", account)
    print("Average balance:", average_balance)
except ZeroDivisionError:
    print("Cannot calculate average balance because the number of days is zero.")
# Out:
# Cannot calculate average balance because the number of days is zero.

# %% [markdown]
# ### Q14. Open a transaction file safely for banking case 2; use sample reference `ACC-1014` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1014"
file_name = "transactions.txt"
try:
    file = open(file_name, "r")
    print("Account:", account)
    print("Transaction file opened successfully.")
    file.close()
except FileNotFoundError:
    print("Transaction file not found.")
# Out:
# Transaction file not found.

# %% [markdown]
# ### Q15. Reject a negative withdrawal for banking case 2; use sample reference `ACC-1015` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1015"
balance = 5000.00
withdrawal = -1000.00

try:
    if withdrawal < 0:
        raise ValueError("Withdrawal amount cannot be negative.")

    balance -= withdrawal

    print("Account:", account)
    print("New balance:", balance)

except ValueError as e:
    print("Withdrawal failed:", e)
# Out:
# Withdrawal failed: Withdrawal amount cannot be negative.

# %% [markdown]
# ### Q16. Catch invalid tenure input for banking case 2; use sample reference `ACC-1016` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1016"
tenure_input = "five"
try:
    tenure = int(tenure_input)
    print("Account:", account)
    print("Loan tenure:", tenure, "years")
except ValueError:
    print("Invalid tenure. Tenure must be a whole number.")
# Out:
# Invalid tenure. Tenure must be a whole number.

# %% [markdown]
# ### Q17. Use else after pin-format validation for banking case 2; use sample reference `ACC-1017` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1017"
pin = "5678"
try:
    if len(pin) != 4 or not pin.isdigit():
        raise ValueError("PIN must contain exactly 4 digits.")
except ValueError as e:
    print("PIN validation failed:", e)
else:
    print("Account:", account)
    print("PIN format is valid.")
# Out:
# Account: ACC-1017
# PIN format is valid.

# %% [markdown]
# ### Q18. Use finally to close a session for banking case 2; use sample reference `ACC-1018` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1018"
session = "Banking session"
try:
    print("Account:", account)
    print("Session opened successfully.")
    print("Processing banking transaction...")
except Exception as e:
    print("Session error:", e)
finally:
    print("Session closed.")
# Out:
# Account: ACC-1018
# Session opened successfully.
# Processing banking transaction...
# Session closed.

# %% [markdown]
# ### Q19. Catch multiple numeric conversion errors for banking case 2; use sample reference `ACC-1019` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1019"
amount = "abc"
tenure = None
try:
    deposit = float(amount)
    years = int(tenure)
    print("Account:", account)
    print("Deposit:", deposit)
    print("Tenure:", years)
except (ValueError, TypeError):
    print("Invalid numeric input.")
# Out:
# Invalid numeric input.

# %% [markdown]
# ### Q20. Raise a clear valueerror for banking case 2; use sample reference `ACC-1020` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1020"
deposit = -500.00
try:
    if deposit <= 0:
        raise ValueError("Deposit amount must be greater than zero.")
    print("Account:", account)
    print("Deposit amount:", deposit)
except ValueError as e:
    print("Deposit failed:", e)
# Out:
# Deposit failed: Deposit amount must be greater than zero.

# %% [markdown]
# ### Q21. Parse a deposit amount for banking case 3; use sample reference `ACC-1021` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1021"
raw = "3000.50"
try:
    deposit = float(raw)
    print("Account:", account)
    print("Deposit amount:", deposit)
except ValueError:
    print("Deposit amount must be a valid number.")
# Out:
# Account: ACC-1021
# Deposit amount: 3000.5

# %% [markdown]
# ### Q22. Handle a missing account key for banking case 3; use sample reference `ACC-1022` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1022"

accounts = {
    "ACC-1001": 5000.00,
    "ACC-1002": 7500.00
}
try:
    balance = accounts[account]
    print("Account:", account)
    print("Balance:", balance)
except KeyError:
    print("Account not found.")
# Out:
# Account not found.

# %% [markdown]
# ### Q23. Prevent division by zero in average balance for banking case 3; use sample reference `ACC-1023` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1023"
total_balance = 7000.00
number_of_days = 0

try:
    average_balance = total_balance / number_of_days
    print("Account:", account)
    print("Average balance:", average_balance)

except ZeroDivisionError:
    print("Cannot calculate average balance because the number of days is zero.")
# Out:
# Cannot calculate average balance because the number of days is zero.

# %% [markdown]
# ### Q24. Open a transaction file safely for banking case 3; use sample reference `ACC-1024` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1024"
file_name = "transactions.txt"
try:
    file = open(file_name, "r")
    print("Account:", account)
    print("Transaction file opened successfully.")
    file.close()
except FileNotFoundError:
    print("Transaction file not found.")
# Out:
# Transaction file not found.

# %% [markdown]
# ### Q25. Reject a negative withdrawal for banking case 3; use sample reference `ACC-1025` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1025"
balance = 6000.00
withdrawal = -500.00
try:
    if withdrawal < 0:
        raise ValueError("Withdrawal amount cannot be negative.")
    balance -= withdrawal
    print("Account:", account)
    print("New balance:", balance)
except ValueError as e:
    print("Withdrawal failed:", e)
# Out:
# Withdrawal failed: Withdrawal amount cannot be negative.

# %% [markdown]
# ### Q26. Catch invalid tenure input for banking case 3; use sample reference `ACC-1026` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1026"
tenure_input = "ten years"
try:
    tenure = int(tenure_input)
    print("Account:", account)
    print("Loan tenure:", tenure, "years")
except ValueError:
    print("Invalid tenure. Tenure must be a whole number.")
# Out:
# Invalid tenure. Tenure must be a whole number.

# %% [markdown]
# ### Q27. Use else after pin-format validation for banking case 3; use sample reference `ACC-1027` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1027"
pin = "2468"
try:
    if len(pin) != 4 or not pin.isdigit():
        raise ValueError("PIN must contain exactly 4 digits.")
except ValueError as e:
    print("PIN validation failed:", e)
else:
    print("Account:", account)
    print("PIN format is valid.")
# Out:
# Account: ACC-1027
# PIN format is valid.

# %% [markdown]
# ### Q28. Use finally to close a session for banking case 3; use sample reference `ACC-1028` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1028"
session = "Banking session"
try:
    print("Account:", account)
    print("Session opened successfully.")
    print("Processing transaction...")
except Exception as e:
    print("Session error:", e)
finally:
    print("Session closed.")
# Out:
# Account: ACC-1028
# Session opened successfully.
# Processing transaction...
# Session closed.

# %% [markdown]
# ### Q29. Catch multiple numeric conversion errors for banking case 3; use sample reference `ACC-1029` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1029"
amount = "abc"
tenure = None
try:
    deposit = float(amount)
    years = int(tenure)
    print("Account:", account)
    print("Deposit:", deposit)
    print("Tenure:", years)
except (ValueError, TypeError):
    print("Invalid numeric input.")
# Out:
# Invalid numeric input.

# %% [markdown]
# ### Q30. Raise a clear valueerror for banking case 3; use sample reference `ACC-1030` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1030"
deposit = -1000.00
try:
    if deposit <= 0:
        raise ValueError("Deposit amount must be greater than zero.")
    print("Account:", account)
    print("Deposit amount:", deposit)
except ValueError as e:
    print("Deposit failed:", e)
# Out:
# Deposit failed: Deposit amount must be greater than zero.

# %% [markdown]
# ---
#
# ## Medium
#
# Reusable components and multi-step workflows.

# %% [markdown]
# ### Q31. Create insufficientfundserror for banking case 1; use sample reference `ACC-1031` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InsufficientFundsError(Exception):
    pass
account = "ACC-1031"
balance = 3000.00
withdrawal = 5000.00
try:
    if withdrawal > balance:
        raise InsufficientFundsError("Insufficient funds for this withdrawal.")
    balance -= withdrawal
    print("Account:", account)
    print("New balance:", balance)
except InsufficientFundsError as e:
    print("Withdrawal failed:", e)
# Out:
# Withdrawal failed: Insufficient funds for this withdrawal.

# %% [markdown]
# ### Q32. Chain invalidtransactionerror from valueerror for banking case 1; use sample reference `ACC-1032` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InvalidTransactionError(Exception):
    pass
account = "ACC-1032"
amount = "abc"
try:
    try:
        value = float(amount)
    except ValueError as e:
        raise InvalidTransactionError("Invalid transaction amount.") from e
    print("Account:", account)
    print("Amount:", value)
except InvalidTransactionError as e:
    print("Transaction failed:", e)
    print("Original cause:", type(e.__cause__).__name__)
# Out:
# Transaction failed: Invalid transaction amount.
# Original cause: ValueError

# %% [markdown]
# ### Q33. Process transfers while isolating bad rows for banking case 1; use sample reference `ACC-1033` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1033"
transfers = [
    ("ACC-2001", 1000),
    ("ACC-2002", -500),
    ("ACC-2003", 750)
]
successful = []
failed = []
for target, amount in transfers:
    try:
        if amount <= 0:
            raise ValueError("Transfer amount must be positive.")
        successful.append((target, amount))
    except ValueError as e:
        failed.append((target, str(e)))
print("Account:", account)
print("Successful transfers:", successful)
print("Failed transfers:", failed)
# Out:
# Account: ACC-1033
# Successful transfers: [('ACC-2001', 1000), ('ACC-2003', 750)]
# Failed transfers: [('ACC-2002', 'Transfer amount must be positive.')]

# %% [markdown]
# ### Q34. Retry a transient payment gateway for banking case 1; use sample reference `ACC-1034` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1034"
attempts = 0
max_attempts = 3
while attempts < max_attempts:
    try:
        attempts += 1
        if attempts < 3:
            raise ConnectionError("Payment gateway temporarily unavailable.")
        print("Account:", account)
        print("Payment successful on attempt", attempts)
        break
    except ConnectionError as e:
        print("Attempt", attempts, "failed:", e)
else:
    print("Payment failed after all attempts.")
# Out:
# Attempt 1 failed: Payment gateway temporarily unavailable.
# Attempt 2 failed: Payment gateway temporarily unavailable.
# Account: ACC-1034
# Payment successful on attempt 3

# %% [markdown]
# ### Q35. Log failed standing instructions for banking case 1; use sample reference `ACC-1035` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
import logging
account = "ACC-1035"
logger = logging.getLogger(__name__)
logger.error("Error message")
for handler in logger.handlers:
    logger.removeHandler(handler)
    logger.handlers = []
try:
    print(account, "New Balance:", balance)
    raise ValueError("Invalid standing instruction")
except ValueError as e:
    print("Error:", e)
# Out:
# ERROR:__main__:Error message
# ACC-1035 New Balance: 7000.0
# Error: Invalid standing instruction

# %% [markdown]
# ### Q36. Return a structured failure result for banking case 1; use sample reference `ACC-1036` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1036"
amount = -500
try:
    if amount <= 0:
        raise ValueError("Amount must be greater than zero.")

    result = {
        "account": account,
        "status": "success",
        "amount": amount
    }
except ValueError as e:
    result = {
        "account": account,
        "status": "failed",
        "error": str(e)
    }
print(result)
# Out:
# {'account': 'ACC-1036', 'status': 'failed', 'error': 'Amount must be greater than zero.'}

# %% [markdown]
# ### Q37. Validate a nested beneficiary record for banking case 1; use sample reference `ACC-1037` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1037"
beneficiary = {
    "details": {
        "name": "Rahul",
        "account": ""
    }
}
try:
    beneficiary_account = beneficiary["details"]["account"]
    if not beneficiary_account:
        raise ValueError("Beneficiary account is missing.")
    print("Account:", account)
    print("Beneficiary account:", beneficiary_account)
except (KeyError, ValueError):
    print("Invalid beneficiary record.")
# Out:
# Invalid beneficiary record.

# %% [markdown]
# ### Q38. Use a context manager for an audit file for banking case 1; use sample reference `ACC-1038` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1038"
file_name = "audit.txt"
try:
    with open(file_name, "w") as file:
        file.write("Audit record for " + account)
    print("Audit record written successfully.")
except OSError:
    print("Unable to write audit record.")
# Out:
# Audit record written successfully.

# %% [markdown]
# ### Q39. Separate validation and recovery for banking case 1; use sample reference `ACC-1039` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1039"
balance = 5000.00
withdrawal = 6000.00
try:
    if withdrawal <= 0:
        raise ValueError("Withdrawal must be positive.")
    if withdrawal > balance:
        raise ValueError("Insufficient balance.")
except ValueError as e:
    print("Validation failed:", e)
    print("Recovery: withdrawal was cancelled.")

else:
    balance -= withdrawal
    print("Withdrawal successful.")
    print("New balance:", balance)
# Out:
# Validation failed: Insufficient balance.
# Recovery: withdrawal was cancelled.

# %% [markdown]
# ### Q40. Collect all kyc validation errors for banking case 1; use sample reference `ACC-1040` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1040"
kyc = {
    "name": "",
    "age": 16,
    "document": ""
}
errors = []
if not kyc["name"]:
    errors.append("Name is missing.")
if kyc["age"] < 18:
    errors.append("Customer must be at least 18 years old.")
if not kyc["document"]:
    errors.append("KYC document is missing.")
if errors:
    print("Account:", account)
    print("KYC validation failed:")
    for error in errors:
        print("-", error)
else:
    print("KYC validation successful.")
# Out:
# Account: ACC-1040
# KYC validation failed:
# - Name is missing.
# - Customer must be at least 18 years old.
# - KYC document is missing.

# %% [markdown]
# ### Q41. Create insufficientfundserror for banking case 2; use sample reference `ACC-1041` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InsufficientFundsError(Exception):
    pass
account = "ACC-1041"
balance = 2500.00
withdrawal = 4000.00
try:
    if withdrawal > balance:
        raise InsufficientFundsError("Insufficient funds.")
    balance -= withdrawal
    print("Account:", account)
    print("New balance:", balance)
except InsufficientFundsError as e:
    print("Transaction failed:", e)
# Out:
# Transaction failed: Insufficient funds.

# %% [markdown]
# ### Q42. Chain invalidtransactionerror from valueerror for banking case 2; use sample reference `ACC-1042` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InvalidTransactionError(Exception):
    pass
account = "ACC-1042"
amount = "invalid"
try:
    try:
        value = float(amount)
    except ValueError as e:
        raise InvalidTransactionError(
            "Transaction contains an invalid amount."
        ) from e
except InvalidTransactionError as e:
    print("Account:", account)
    print("Transaction failed:", e)
    print("Original cause:", type(e.__cause__).__name__)
# Out:
# Account: ACC-1042
# Transaction failed: Transaction contains an invalid amount.
# Original cause: ValueError

# %% [markdown]
# ### Q43. Process transfers while isolating bad rows for banking case 2; use sample reference `ACC-1043` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1043"
transfers = [
    ("ACC-3001", 500),
    ("ACC-3002", 0),
    ("ACC-3003", 1200)
]
successful = []
failed = []
for target, amount in transfers:
    try:
        if amount <= 0:
            raise ValueError("Transfer amount must be greater than zero.")
        successful.append((target, amount))
    except ValueError as e:
        failed.append({
            "target": target,
            "error": str(e)
        })
print("Account:", account)
print("Successful:", successful)
print("Failed:", failed)
# Out:
# Account: ACC-1043
# Successful: [('ACC-3001', 500), ('ACC-3003', 1200)]
# Failed: [{'target': 'ACC-3002', 'error': 'Transfer amount must be greater than zero.'}]

# %% [markdown]
# ### Q44. Retry a transient payment gateway for banking case 2; use sample reference `ACC-1044` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1044"
attempt = 0
max_attempts = 3
while attempt < max_attempts:
    try:
        attempt += 1
        if attempt < 2:
            raise TimeoutError("Payment gateway timed out.")
        print("Account:", account)
        print("Payment successful on attempt", attempt)
        break
    except TimeoutError as e:
        print("Attempt", attempt, "failed:", e)
else:
    print("Payment failed after all attempts.")
# Out:
# Attempt 1 failed: Payment gateway timed out.
# Account: ACC-1044
# Payment successful on attempt 2

# %% [markdown]
# ### Q45. Log failed standing instructions for banking case 2; use sample reference `ACC-1045` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1045"
balance = 2000
def log_failed_standing_instructions(account):
    try:
        return {"account": account, "balance": balance}
    except ValueError as e:
        print("Error:", e)
print(log_failed_standing_instructions(account))
# Out:
# {'account': 'ACC-1045', 'balance': 2000}

# %% [markdown]
# ### Q46. Return a structured failure result for banking case 2; use sample reference `ACC-1046` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1046"
amount = -800.00
try:
    if amount <= 0:
        raise ValueError("Transaction amount must be greater than zero.")
    result = {
        "account": account,
        "status": "success",
        "amount": amount
    }
except ValueError as e:
    result = {
        "account": account,
        "status": "failed",
        "error": str(e)
    }
print(result)
# Out:
# {'account': 'ACC-1046', 'status': 'failed', 'error': 'Transaction amount must be greater than zero.'}

# %% [markdown]
# ### Q47. Validate a nested beneficiary record for banking case 2; use sample reference `ACC-1047` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1047"
beneficiary = {
    "details": {
        "name": "Anita",
        "account": ""
    }
}

try:
    beneficiary_account = beneficiary["details"]["account"]
    if not beneficiary_account:
        raise ValueError("Beneficiary account is missing.")
    print("Account:", account)
    print("Beneficiary account:", beneficiary_account)
except (KeyError, ValueError):
    print("Invalid beneficiary record.")
# Out:
# Invalid beneficiary record.

# %% [markdown]
# ### Q48. Use a context manager for an audit file for banking case 2; use sample reference `ACC-1048` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1048"
file_name = "audit.txt"
try:
    with open(file_name, "w") as file:
        file.write("Audit record for " + account)
    print("Audit record written successfully.")
except OSError:
    print("Unable to write audit record.")
# Out:
# Audit record written successfully.

# %% [markdown]
# ### Q49. Separate validation and recovery for banking case 2; use sample reference `ACC-1049` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1049"
balance = 4000.00
withdrawal = 5000.00
try:
    if withdrawal <= 0:
        raise ValueError("Withdrawal must be positive.")
    if withdrawal > balance:
        raise ValueError("Insufficient balance.")
except ValueError as e:
    print("Validation failed:", e)
    print("Recovery: withdrawal cancelled.")
else:
    balance -= withdrawal
    print("Account:", account)
# Out:
# Validation failed: Insufficient balance.
# Recovery: withdrawal cancelled.

# %% [markdown]
# ### Q50. Collect all kyc validation errors for banking case 2; use sample reference `ACC-1050` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1050"
kyc = {
    "name": "",
    "age": 17,
    "document": ""
}
errors = []
if not kyc["name"]:
    errors.append("Name is missing.")
if kyc["age"] < 18:
    errors.append("Customer must be at least 18 years old.")
if not kyc["document"]:
    errors.append("KYC document is missing.")
if errors:
    print("Account:", account)
    print("KYC validation failed:")
    for error in errors:
        print("-", error)
else:
    print("KYC validation successful.")
# Out:
# Account: ACC-1050
# KYC validation failed:
# - Name is missing.
# - Customer must be at least 18 years old.
# - KYC document is missing.

# %% [markdown]
# ### Q51. Create insufficientfundserror for banking case 3; use sample reference `ACC-1051` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InsufficientFundsError(Exception):
    pass
account = "ACC-1051"
balance = 3000.00
withdrawal = 4500.00
try:
    if withdrawal > balance:
        raise InsufficientFundsError("Insufficient funds for withdrawal.")
    balance -= withdrawal
    print("Account:", account)
    print("New balance:", balance)
except InsufficientFundsError as e:
    print("Withdrawal failed:", e)
# Out:
# Withdrawal failed: Insufficient funds for withdrawal.

# %% [markdown]
# ### Q52. Chain invalidtransactionerror from valueerror for banking case 3; use sample reference `ACC-1052` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InvalidTransactionError(Exception):
    pass
account = "ACC-1052"
amount = "abc"
try:
    try:
        value = float(amount)
    except ValueError as e:
        raise InvalidTransactionError(
            "Invalid transaction amount."
        ) from e
    print("Account:", account)
    print("Transaction amount:", value)
except InvalidTransactionError as e:
    print("Transaction failed:", e)
    print("Original cause:", type(e.__cause__).__name__)
# Out:
# Transaction failed: Invalid transaction amount.
# Original cause: ValueError

# %% [markdown]
# ### Q53. Process transfers while isolating bad rows for banking case 3; use sample reference `ACC-1053` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1053"
transfers = [
    ("ACC-2001", 1000),
    ("ACC-2002", -500),
    ("ACC-2003", 750)
]
successful = []
failed = []
for target, amount in transfers:
    try:
        if amount <= 0:
            raise ValueError("Transfer amount must be positive.")
        successful.append((target, amount))
    except ValueError as e:
        failed.append((target, str(e)))
print("Account:", account)
print("Successful transfers:", successful)
print("Failed transfers:", failed)
# Out:
# Account: ACC-1053
# Successful transfers: [('ACC-2001', 1000), ('ACC-2003', 750)]
# Failed transfers: [('ACC-2002', 'Transfer amount must be positive.')]

# %% [markdown]
# ### Q54. Retry a transient payment gateway for banking case 3; use sample reference `ACC-1054` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1054"
attempt = 0
max_attempts = 3
while attempt < max_attempts:
    try:
        attempt += 1
        if attempt < 3:
            raise ConnectionError("Payment gateway temporarily unavailable.")
        print("Account:", account)
        print("Payment successful on attempt", attempt)
        break
    except ConnectionError as e:
        print("Attempt", attempt, "failed:", e)
else:
    print("Payment failed after all attempts.")
# Out:
# Attempt 1 failed: Payment gateway temporarily unavailable.
# Attempt 2 failed: Payment gateway temporarily unavailable.
# Account: ACC-1054
# Payment successful on attempt 3

# %% [markdown]
# ### Q55. Log failed standing instructions for banking case 3; use sample reference `ACC-1055` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
def log_failed_standing_instructions(reference, message):
    with open("audit.log", "a") as audit_file:
        audit_file.write(f"{reference}: {message}\n")
    return {
        "reference": reference,
        "status": "SUCCESS",
        "message": "Audit record written successfully"
    }
result = log_failed_standing_instructions(
    "ACC-1055",
    "Standing instructions failed"
)
print(result)
# Out:
# {'reference': 'ACC-1055', 'status': 'SUCCESS', 'message': 'Audit record written successfully'}

# %% [markdown]
# ### Q56. Return a structured failure result for banking case 3; use sample reference `ACC-1056` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1056"
amount = -500
try:
    if amount <= 0:
        raise ValueError("Amount must be greater than zero.")
    result = {
        "account": account,
        "status": "success",
        "amount": amount
    }
except ValueError as e:
    result = {
        "account": account,
        "status": "failed",
        "error": str(e)
    }
print(result)
# Out:
# {'account': 'ACC-1056', 'status': 'failed', 'error': 'Amount must be greater than zero.'}

# %% [markdown]
# ### Q57. Validate a nested beneficiary record for banking case 3; use sample reference `ACC-1057` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1057"
beneficiary = {
    "details": {
        "name": "Anita",
        "account": ""
    }
}
try:
    beneficiary_account = beneficiary["details"]["account"]
    if not beneficiary_account:
        raise ValueError("Beneficiary account is missing.")
    print("Account:", account)
    print("Beneficiary account:", beneficiary_account)
except (KeyError, ValueError):
    print("Invalid beneficiary record.")
# Out:
# Invalid beneficiary record.

# %% [markdown]
# ### Q58. Use a context manager for an audit file for banking case 3; use sample reference `ACC-1058` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1058"
file_name = "audit.txt"
try:
    with open(file_name, "w") as file:
        file.write("Audit record for " + account)
    print("Audit record written successfully.")
except OSError:
    print("Unable to write audit record.")
# Out:
# Audit record written successfully.

# %% [markdown]
# ### Q59. Separate validation and recovery for banking case 3; use sample reference `ACC-1059` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1059"
balance = 4000.00
withdrawal = 5000.00
try:
    if withdrawal <= 0:
        raise ValueError("Withdrawal must be positive.")
    if withdrawal > balance:
        raise ValueError("Insufficient balance.")
except ValueError as e:
    print("Validation failed:", e)
    print("Recovery: withdrawal cancelled.")
else:
    balance -= withdrawal
    print("Account:", account)
    print("New balance:", balance)
# Out:
# Validation failed: Insufficient balance.
# Recovery: withdrawal cancelled.

# %% [markdown]
# ### Q60. Collect all kyc validation errors for banking case 3; use sample reference `ACC-1060` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1060"
kyc = {
    "name": "",
    "age": 16,
    "document": ""
}
errors = []
if not kyc["name"]:
    errors.append("Name is missing.")
if kyc["age"] < 18:
    errors.append("Customer must be at least 18 years old.")
if not kyc["document"]:
    errors.append("KYC document is missing.")
if errors:
    print("Account:", account)
    print("KYC validation failed:")
for error in errors:
        print("-", error)
else:
    print("KYC validation successful.")
# Out:
# Account: ACC-1060
# KYC validation failed:
# - Name is missing.
# - Customer must be at least 18 years old.
# - KYC document is missing.
# KYC validation successful.

# %% [markdown]
# ### Q61. Create insufficientfundserror for banking case 4; use sample reference `ACC-1061` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InsufficientFundsError(Exception):
    pass
account = "ACC-1061"
balance = 2500.00
withdrawal = 4000.00
try:
    if withdrawal > balance:
        raise InsufficientFundsError("Insufficient funds for withdrawal.")
    balance -= withdrawal
    print("Account:", account)
    print("New balance:", balance)
except InsufficientFundsError as e:
    print("Withdrawal failed:", e)
# Out:
# Withdrawal failed: Insufficient funds for withdrawal.

# %% [markdown]
# ### Q62. Chain invalidtransactionerror from valueerror for banking case 4; use sample reference `ACC-1062` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class InvalidTransactionError(Exception):
    pass
account = "ACC-1062"
amount = "abc"
try:
    try:
        value = float(amount)
    except ValueError as e:
        raise InvalidTransactionError("Invalid transaction amount.") from e
    print("Account:", account)
    print("Transaction amount:", value)
except InvalidTransactionError as e:
    print("Transaction failed:", e)
    print("Original cause:", type(e.__cause__).__name__)
# Out:
# Transaction failed: Invalid transaction amount.
# Original cause: ValueError

# %% [markdown]
# ### Q63. Process transfers while isolating bad rows for banking case 4; use sample reference `ACC-1063` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1063"
transfers = [
    ("ACC-3001", 1000),
    ("ACC-3002", -500),
    ("ACC-3003", 750)
]
successful = []
failed = []
for target, amount in transfers:
    try:
        if amount <= 0:
            raise ValueError("Transfer amount must be positive.")
        successful.append((target, amount))
    except ValueError as e:
        failed.append((target, str(e)))
print("Account:", account)
print("Successful transfers:", successful)
print("Failed transfers:", failed)
# Out:
# Account: ACC-1063
# Successful transfers: [('ACC-3001', 1000), ('ACC-3003', 750)]
# Failed transfers: [('ACC-3002', 'Transfer amount must be positive.')]

# %% [markdown]
# ### Q64. Retry a transient payment gateway for banking case 4; use sample reference `ACC-1064` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1064"
attempt = 0
max_attempts = 3
while attempt < max_attempts:
    try:
        attempt += 1

        if attempt < 3:
            raise ConnectionError("Payment gateway temporarily unavailable.")
        print("Account:", account)
        print("Payment successful on attempt", attempt)
        break
    except ConnectionError as e:
        print("Attempt", attempt, "failed:", e)
else:
    print("Payment failed after all attempts.")
# Out:
# Attempt 1 failed: Payment gateway temporarily unavailable.
# Attempt 2 failed: Payment gateway temporarily unavailable.
# Account: ACC-1064
# Payment successful on attempt 3

# %% [markdown]
# ### Q65. Log failed standing instructions for banking case 4; use sample reference `ACC-1065` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class log_failed_standing_instructions(Exception):
    pass
reference = "ACC-1065"
message = "Standing instructions failed"
with open("audit.log", "a") as audit_file:
    audit_file.write(f"{reference}: {message}\n")
print("Audit record written successfully.")
print("Reference:", reference)
print("Message:", message)
# Out:
# Audit record written successfully.
# Reference: ACC-1065
# Message: Standing instructions failed

# %% [markdown]
# ### Q66. Return a structured failure result for banking case 4; use sample reference `ACC-1066` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1066"
amount = -500

try:
    if amount <= 0:
        raise ValueError("Amount must be greater than zero.")

    result = {
        "account": account,
        "status": "success",
        "amount": amount
    }

except ValueError as e:
    result = {
        "account": account,
        "status": "failed",
        "error": str(e)
    }

print(result)
# Out:
# {'account': 'ACC-1066', 'status': 'failed', 'error': 'Amount must be greater than zero.'}

# %% [markdown]
# ### Q67. Validate a nested beneficiary record for banking case 4; use sample reference `ACC-1067` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1067"
beneficiary = {
    "details": {
        "name": "Anita",
        "account": ""
    }
}
try:
    beneficiary_account = beneficiary["details"]["account"]
    if not beneficiary_account:
        raise ValueError("Beneficiary account is missing.")
    print("Account:", account)
    print("Beneficiary account:", beneficiary_account)
except (KeyError, ValueError):
    print("Invalid beneficiary record.")
# Out:
# Invalid beneficiary record.

# %% [markdown]
# ### Q68. Use a context manager for an audit file for banking case 4; use sample reference `ACC-1068` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1068"
file_name = "audit.txt"
try:
    with open(file_name, "w") as file:
        file.write("Audit record for " + account)

    print("Audit record written successfully.")
except OSError:
    print("Unable to write audit record.")
# Out:
# Audit record written successfully.

# %% [markdown]
# ### Q69. Separate validation and recovery for banking case 4; use sample reference `ACC-1069` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1069"
balance = 4000.00
withdrawal = 5000.00
try:
    if withdrawal <= 0:
        raise ValueError("Withdrawal must be positive.")
    if withdrawal > balance:
        raise ValueError("Insufficient balance.")
except ValueError as e:
    print("Validation failed:", e)
    print("Recovery: withdrawal cancelled.")
else:
    balance -= withdrawal
    print("Account:", account)
    print("New balance:", balance)
# Out:
# Validation failed: Insufficient balance.
# Recovery: withdrawal cancelled.

# %% [markdown]
# ### Q70. Collect all kyc validation errors for banking case 4; use sample reference `ACC-1070` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1070"
kyc = {
    "name": "",
    "age": 16,
    "document": ""
}
errors = []
if not kyc["name"]:
    errors.append("Name is missing.")
if kyc["age"] < 18:
    errors.append("Customer must be at least 18 years old.")
if not kyc["document"]:
    errors.append("KYC document is missing.")
if errors:
    print("Account:", account)
    print("KYC validation failed:")
for error in errors:
        print("-", error)
else:
    print("KYC validation successful.")
# Out:
# Account: ACC-1070
# KYC validation failed:
# - Name is missing.
# - Customer must be at least 18 years old.
# - KYC document is missing.
# KYC validation successful.

# %% [markdown]
# ---
#
# ## Difficult
#
# Architecture, edge cases, and end-to-end banking systems.

# %% [markdown]
# ### Q71. Design a banking exception hierarchy for banking case 1; use sample reference `ACC-1071` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankingError(Exception):
    pass
class InsufficientFundsError(BankingError):
    pass
class InvalidTransactionError(BankingError):
    pass
account = "ACC-1071"
balance = 2000.00
withdrawal = 3000.00
try:
    if withdrawal <= 0:
        raise InvalidTransactionError("Withdrawal amount must be positive.")
    if withdrawal > balance:
        raise InsufficientFundsError("Insufficient funds.")
    balance -= withdrawal
    print("Withdrawal successful.")
    print("New balance:", balance)
except InsufficientFundsError as e:
    print("Banking error:", e)
except InvalidTransactionError as e:
    print("Transaction error:", e)
# Out:
# Banking error: Insufficient funds.

# %% [markdown]
# ### Q72. Make a transfer rollback-safe for banking case 1; use sample reference `ACC-1072` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1072"
balances = {
    "ACC-1072": 5000.00,
    "ACC-2001": 1000.00
}
amount = 2000.00
original_sender = balances["ACC-1072"]
original_receiver = balances["ACC-2001"]
try:
    balances["ACC-1072"] -= amount
    raise ConnectionError("Receiver service unavailable.")
    balances["ACC-2001"] += amount
except ConnectionError as e:
    balances["ACC-1072"] = original_sender
    balances["ACC-2001"] = original_receiver
    print("Transfer failed:", e)
    print("Transaction rolled back.")
    print("Balances:", balances)
# Out:
# Transfer failed: Receiver service unavailable.
# Transaction rolled back.
# Balances: {'ACC-1072': 5000.0, 'ACC-2001': 1000.0}

# %% [markdown]
# ### Q73. Preserve causes across service layers for banking case 1; use sample reference `ACC-1073` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentServiceError(Exception):
    pass
def database_layer():
    raise ConnectionError("Database connection failed.")
def payment_service():
    try:
        database_layer()
    except ConnectionError as e:
        raise PaymentServiceError("Payment service failed.") from e
account = "ACC-1073"
try:
    payment_service()
except PaymentServiceError as e:
    print("Account:", account)
    print("Service error:", e)
    print("Original cause:", type(e.__cause__).__name__)
# Out:
# Account: ACC-1073
# Service error: Payment service failed.
# Original cause: ConnectionError

# %% [markdown]
# ### Q74. Implement bounded exponential retry for banking case 1; use sample reference `ACC-1074` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
import time
account = "ACC-1074"
max_attempts = 3
base_delay = 1
for attempt in range(1, max_attempts + 1):
    try:
        if attempt < 3:
            raise ConnectionError("Payment gateway unavailable.")
        print("Account:", account)
        print("Payment successful on attempt", attempt)
        break
    except ConnectionError as e:
        print("Attempt", attempt, "failed:", e)
        if attempt == max_attempts:
            print("Maximum retry limit reached.")
        else:
            delay = min(base_delay * (2 ** (attempt - 1)), 4)
            print("Retrying after", delay, "second(s)...")
            time.sleep(0.1)
# Out:
# Attempt 1 failed: Payment gateway unavailable.
# Retrying after 1 second(s)...
# Attempt 2 failed: Payment gateway unavailable.
# Retrying after 2 second(s)...
# Account: ACC-1074
# Payment successful on attempt 3

# %% [markdown]
# ### Q75. Create a transaction context manager for banking case 1; use sample reference `ACC-1075` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transaction:
    def __init__(self, balance):
        self.balance = balance
        self.original_balance = balance

    def __enter__(self):
        print("Transaction started.")
        return self

    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            self.balance = self.original_balance
            print("Transaction failed. Rolled back.")
        else:
            print("Transaction committed.")

        return False


account = "ACC-1075"
balance = 5000.00

try:
  with Transaction(balance) as transaction:
        transaction.balance -= 1500

        raise ValueError("Transaction processing failed.")

except ValueError as e:
    print("Account:", account)
    print("Error:", e)
# Out:
# Transaction started.
# Transaction failed. Rolled back.
# Account: ACC-1075
# Error: Transaction processing failed.

# %% [markdown]
# ### Q76. Build a dead-letter queue for payment events for banking case 1; use sample reference `ACC-1076` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1076"
payment_events = [
    {"id": "P001", "amount": 500},
    {"id": "P002", "amount": -100},
    {"id": "P003", "amount": 750}
]
dead_letter_queue = []
successful = []
for event in payment_events:
    try:
        if event["amount"] <= 0:
            raise ValueError("Invalid payment amount.")
        successful.append(event)
    except (KeyError, ValueError) as e:
        dead_letter_queue.append({
            "event": event,
            "error": str(e)
        })
print("Account:", account)
print("Successful events:", successful)
print("Dead-letter queue:", dead_letter_queue)
# Out:
# Account: ACC-1076
# Successful events: [{'id': 'P001', 'amount': 500}, {'id': 'P003', 'amount': 750}]
# Dead-letter queue: [{'event': {'id': 'P002', 'amount': -100}, 'error': 'Invalid payment amount.'}]

# %% [markdown]
# ### Q77. Make batch settlement failure-isolated for banking case 1; use sample reference `ACC-1077` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1077"
settlements = [
    {"id": "S001", "amount": 1000},
    {"id": "S002", "amount": -500},
    {"id": "S003", "amount": 1500}
]
successful = []
failed = []
for settlement in settlements:
    try:
        if settlement["amount"] <= 0:
            raise ValueError("Settlement amount must be positive.")

        successful.append(settlement)

    except ValueError as e:
        failed.append({
            "id": settlement["id"],
            "reason": str(e)
        })
print("Account:", account)
print("Successful settlements:", successful)
print("Failed settlements:", failed)
# Out:
# Account: ACC-1077
# Successful settlements: [{'id': 'S001', 'amount': 1000}, {'id': 'S003', 'amount': 1500}]
# Failed settlements: [{'id': 'S002', 'reason': 'Settlement amount must be positive.'}]

# %% [markdown]
# ### Q78. Report exact paths in nested statements for banking case 1; use sample reference `ACC-1078` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1078"
customer = {
    "profile": {
        "address": {
            "city": "Bangalore"
        }
    }
}
try:
    city = customer["profile"]["address"]["zipcode"]
except KeyError as e:
    print("Account:", account)
    print("Missing path: profile -> address ->", e)
# Out:
# Account: ACC-1078
# Missing path: profile -> address -> 'zipcode'

# %% [markdown]
# ### Q79. Design idempotent recovery after timeout for banking case 1; use sample reference `ACC-1079` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1079"
transaction_id = "TXN-1001"
amount = 1000.00
processed_transactions = {
    "TXN-1001": 1000.00
}
try:
    if transaction_id in processed_transactions:
        print("Transaction already processed.")
        print("No duplicate debit performed.")
    else:
        processed_transactions[transaction_id] = amount
        print("Transaction processed successfully.")
except Exception as e:
    print("Transaction recovery failed:", e)
print("Account:", account)
print("Processed transactions:", processed_transactions)
# Out:
# Transaction already processed.
# No duplicate debit performed.
# Account: ACC-1079
# Processed transactions: {'TXN-1001': 1000.0}

# %% [markdown]
# ### Q80. Build an exception-safe reconciliation pipeline for banking case 1; use sample reference `ACC-1080` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1080"
bank_records = [
    {"id": "T001", "amount": 1000},
    {"id": "T002", "amount": 2000},
    {"id": "T003", "amount": -500}
    ]
ledger_total = 3000
successful = []
failed = []
for record in bank_records:
    try:
        amount = record["amount"]
        if amount <= 0:
            raise ValueError("Invalid transaction amount.")
        successful.append(record)
    except (KeyError, ValueError) as e:
        failed.append({
            "id": record.get("id", "UNKNOWN"),
            "error": str(e)
        })
bank_total = sum(record["amount"] for record in successful)
print("Account:", account)
print("Bank total:", bank_total)
print("Ledger total:", ledger_total)
if bank_total == ledger_total:
    print("Reconciliation successful.")
else:
    print("Reconciliation mismatch.")
print("Failed records:", failed)
# Out:
# Account: ACC-1080
# Bank total: 3000
# Ledger total: 3000
# Reconciliation successful.
# Failed records: [{'id': 'T003', 'error': 'Invalid transaction amount.'}]

# %% [markdown]
# ### Q81. Design a banking exception hierarchy for banking case 2; use sample reference `ACC-1081` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankingError(Exception):
    pass
class InsufficientFundsError(BankingError):
    pass
class InvalidTransactionError(BankingError):
    pass
account = "ACC-1081"
balance = 2500.00
withdrawal = 3000.00
try:
    if withdrawal <= 0:
        raise InvalidTransactionError("Withdrawal amount must be positive.")
    if withdrawal > balance:
        raise InsufficientFundsError("Insufficient funds.")
    balance -= withdrawal
    print("Withdrawal successful.")
    print("New balance:", balance)
except InsufficientFundsError as e:
    print("Banking error:", e)
except InvalidTransactionError as e:
    print("Transaction error:", e)
# Out:
# Banking error: Insufficient funds.

# %% [markdown]
# ### Q82. Make a transfer rollback-safe for banking case 2; use sample reference `ACC-1082` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1082"
balances = {
    "ACC-1082": 5000.00,
    "ACC-2002": 1000.00
}
amount = 2000.00
original_balances = balances.copy()
try:
    balances["ACC-1082"] -= amount
    raise ConnectionError("Receiver service unavailable.")
    balances["ACC-2002"] += amount
except ConnectionError as e:
  balances = original_balances
  print("Transfer failed:", e)
  print("Transaction rolled back.")
print("Account:", account)
print("Balances:", balances)
# Out:
# Transfer failed: Receiver service unavailable.
# Transaction rolled back.
# Account: ACC-1082
# Balances: {'ACC-1082': 5000.0, 'ACC-2002': 1000.0}

# %% [markdown]
# ### Q83. Preserve causes across service layers for banking case 2; use sample reference `ACC-1083` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentServiceError(Exception):
    pass
def database_layer():
    raise ConnectionError("Database connection failed.")
def payment_service():
    try:
        database_layer()
    except ConnectionError as e:
        raise PaymentServiceError(
            "Payment service failed."
        ) from e
account = "ACC-1083"
try:
    payment_service()
except PaymentServiceError as e:
    print("Account:", account)
    print("Service error:", e)
    print("Original cause:", type(e.__cause__).__name__)
# Out:
# Account: ACC-1083
# Service error: Payment service failed.
# Original cause: ConnectionError

# %% [markdown]
# ### Q84. Implement bounded exponential retry for banking case 2; use sample reference `ACC-1084` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
import time
account = "ACC-1084"
max_attempts = 3
base_delay = 1
for attempt in range(1, max_attempts + 1):
    try:
        if attempt < 3:
            raise ConnectionError("Payment gateway unavailable.")
        print("Account:", account)
        print("Payment successful on attempt", attempt)
        break
    except ConnectionError as e:
        print("Attempt", attempt, "failed:", e)
        if attempt == max_attempts:
            print("Maximum retry limit reached.")
        else:
            delay = min(base_delay * (2 ** (attempt - 1)), 4)
            print("Retry delay:", delay, "second(s)")
            time.sleep(0.1)
# Out:
# Attempt 1 failed: Payment gateway unavailable.
# Retry delay: 1 second(s)
# Attempt 2 failed: Payment gateway unavailable.
# Retry delay: 2 second(s)
# Account: ACC-1084
# Payment successful on attempt 3

# %% [markdown]
# ### Q85. Create a transaction context manager for banking case 2; use sample reference `ACC-1085` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transaction:
    def __init__(self, balance):
        self.balance = balance
        self.original_balance = balance
    def __enter__(self):
        print("Transaction started.")
        return self
    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            self.balance = self.original_balance
            print("Transaction failed. Rollback performed.")
        else:
            print("Transaction committed.")
        return False
account = "ACC-1085"
balance = 5000.00
try:
    with Transaction(balance) as transaction:
        transaction.balance -= 1000
        raise ValueError("Transaction processing failed.")
except ValueError as e:
    print("Account:", account)
    print("Error:", e)
# Out:
# Transaction started.
# Transaction failed. Rollback performed.
# Account: ACC-1085
# Error: Transaction processing failed.

# %% [markdown]
# ### Q86. Build a dead-letter queue for payment events for banking case 2; use sample reference `ACC-1086` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1086"
payment_events = [
    {"id": "P001", "amount": 500},
    {"id": "P002", "amount": -100},
    {"id": "P003", "amount": 750}
]
successful = []
dead_letter_queue = []
for event in payment_events:
    try:
        if event["amount"] <= 0:
            raise ValueError("Invalid payment amount.")
            successful.append(event)
    except (KeyError, ValueError) as e:
        dead_letter_queue.append({
            "event": event,
            "error": str(e)
        })
print("Account:", account)
print("Successful payments:", successful)
print("Dead-letter queue:", dead_letter_queue)
# Out:
# Account: ACC-1086
# Successful payments: []
# Dead-letter queue: [{'event': {'id': 'P002', 'amount': -100}, 'error': 'Invalid payment amount.'}]

# %% [markdown]
# ### Q87. Make batch settlement failure-isolated for banking case 2; use sample reference `ACC-1087` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1087"
settlements = [
    {"id": "S001", "amount": 1000},
    {"id": "S002", "amount": -500},
    {"id": "S003", "amount": 1500}
]
successful = []
failed = []
for settlement in settlements:
    try:
        if settlement["amount"] <= 0:
            raise ValueError("Settlement amount must be positive.")
        successful.append(settlement)
    except ValueError as e:
        failed.append({
            "id": settlement["id"],
            "error": str(e)
        })
print("Account:", account)
print("Successful:", successful)
print("Failed:", failed)
# Out:
# Account: ACC-1087
# Successful: [{'id': 'S001', 'amount': 1000}, {'id': 'S003', 'amount': 1500}]
# Failed: [{'id': 'S002', 'error': 'Settlement amount must be positive.'}]

# %% [markdown]
# ### Q88. Report exact paths in nested statements for banking case 2; use sample reference `ACC-1088` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1088"
customer = {
    "profile": {
        "address": {
            "city": "Bangalore"
        }
    }
}
try:
    zipcode = customer["profile"]["address"]["zipcode"]
except KeyError as e:
    print("Account:", account)
    print("Missing path: customer -> profile -> address ->", e)
# Out:
# Account: ACC-1088
# Missing path: customer -> profile -> address -> 'zipcode'

# %% [markdown]
# ### Q89. Design idempotent recovery after timeout for banking case 2; use sample reference `ACC-1089` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1089"
transaction_id = "TXN-1089"
amount = 1000.00
processed_transactions = {
    "TXN-1089": 1000.00
}
try:
    if transaction_id in processed_transactions:
        print("Transaction already processed.")
        print("No duplicate transaction performed.")
    else:
        processed_transactions[transaction_id] = amount
        print("Transaction processed successfully.")
except Exception as e:
    print("Recovery failed:", e)
print("Account:", account)
print("Processed transactions:", processed_transactions)
# Out:
# Transaction already processed.
# No duplicate transaction performed.
# Account: ACC-1089
# Processed transactions: {'TXN-1089': 1000.0}

# %% [markdown]
# ### Q90. Build an exception-safe reconciliation pipeline for banking case 2; use sample reference `ACC-1090` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1090"
bank_records = [
    {"id": "T001", "amount": 1000},
    {"id": "T002", "amount": 2000},
    {"id": "T003", "amount": -500}
]
ledger_total = 3000
successful = []
failed = []
for record in bank_records:
    try:
        amount = record["amount"]
        if amount <= 0:
            raise ValueError("Invalid transaction amount.")
        successful.append(record)
    except (KeyError, ValueError) as e:
      failed.append({
            "id": record.get("id", "UNKNOWN"),
            "error": str(e)
        })
bank_total = sum(record["amount"] for record in successful)
print("Account:", account)
print("Bank total:", bank_total)
print("Ledger total:", ledger_total)
if bank_total == ledger_total:
    print("Reconciliation successful.")
else:
    print("Reconciliation mismatch.")
print("Failed records:", failed)
# Out:
# Account: ACC-1090
# Bank total: 3000
# Ledger total: 3000
# Reconciliation successful.
# Failed records: [{'id': 'T003', 'error': 'Invalid transaction amount.'}]

# %% [markdown]
# ### Q91. Design a banking exception hierarchy for banking case 3; use sample reference `ACC-1091` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankingError(Exception):
    pass
class InsufficientFundsError(BankingError):
    pass
class InvalidTransactionError(BankingError):
    pass
account = "ACC-1091"
balance = 4000.00
withdrawal = 5000.00
try:
    if withdrawal <= 0:
        raise InvalidTransactionError("Withdrawal amount must be positive.")
    if withdrawal > balance:
        raise InsufficientFundsError("Insufficient funds.")
    balance -= withdrawal
    print("Withdrawal successful.")
    print("New balance:", balance)
except InsufficientFundsError as e:
    print("Banking error:", e)
except InvalidTransactionError as e:
    print("Transaction error:", e)
# Out:
# Banking error: Insufficient funds.

# %% [markdown]
# ### Q92. Make a transfer rollback-safe for banking case 3; use sample reference `ACC-1092` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1092"
balances = {
    "ACC-1092": 6000.00,
    "ACC-3001": 1500.00
}
amount = 2500.00
original_balances = balances.copy()
try:
    balances["ACC-1092"] -= amount
    raise ConnectionError("Receiver account service unavailable.")
    balances["ACC-3001"] += amount
except ConnectionError as e:
    balances = original_balances
    print("Transfer failed:", e)
    print("Transaction rolled back.")
print("Account:", account)
print("Balances:", balances)
# Out:
# Transfer failed: Receiver account service unavailable.
# Transaction rolled back.
# Account: ACC-1092
# Balances: {'ACC-1092': 6000.0, 'ACC-3001': 1500.0}

# %% [markdown]
# ### Q93. Preserve causes across service layers for banking case 3; use sample reference `ACC-1093` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BankingServiceError(Exception):
    pass
def database_service():
    raise ConnectionError("Database connection failed.")
def account_service():
    try:
        database_service()
    except ConnectionError as e:
        raise BankingServiceError(
            "Account service failed."
        ) from e
account = "ACC-1093"
try:
    account_service()
except BankingServiceError as e:
    print("Account:", account)
    print("Service error:", e)
    print("Original cause:", type(e.__cause__).__name__)
# Out:
# Account: ACC-1093
# Service error: Account service failed.
# Original cause: ConnectionError

# %% [markdown]
# ### Q94. Implement bounded exponential retry for banking case 3; use sample reference `ACC-1094` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
import time
account = "ACC-1094"
max_attempts = 3
base_delay = 1
for attempt in range(1, max_attempts + 1):
    try:
        if attempt < 3:
            raise ConnectionError("Payment gateway unavailable.")
        print("Account:", account)
        print("Payment successful on attempt", attempt)
        break
    except ConnectionError as e:
        print("Attempt", attempt, "failed:", e)
        if attempt == max_attempts:
            print("Maximum retry limit reached.")
        else:
            delay = base_delay * (2 ** (attempt - 1))
            print("Retry delay:", delay, "second(s)")
            time.sleep(0.1)
# Out:
# Attempt 1 failed: Payment gateway unavailable.
# Retry delay: 1 second(s)
# Attempt 2 failed: Payment gateway unavailable.
# Retry delay: 2 second(s)
# Account: ACC-1094
# Payment successful on attempt 3

# %% [markdown]
# ### Q95. Create a transaction context manager for banking case 3; use sample reference `ACC-1095` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transaction:
    def __init__(self, balance):
        self.balance = balance
        self.original_balance = balance
    def __enter__(self):
        print("Transaction started.")
        return self
    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            self.balance = self.original_balance
            print("Transaction failed. Rollback performed.")
        else:
            print("Transaction committed.")
        return False
account = "ACC-1095"
balance = 7000.00
try:
    with Transaction(balance) as transaction:
        transaction.balance -= 2000
        raise ValueError("Transaction processing failed.")
except ValueError as e:
    print("Account:", account)
    print("Error:", e)
# Out:
# Transaction started.
# Transaction failed. Rollback performed.
# Account: ACC-1095
# Error: Transaction processing failed.

# %% [markdown]
# ### Q96. Build a dead-letter queue for payment events for banking case 3; use sample reference `ACC-1096` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1096"
payment_events = [
    {"id": "P101", "amount": 500},
    {"id": "P102", "amount": -200},
    {"id": "P103", "amount": 800}
]
successful = []
dead_letter_queue = []
for event in payment_events:
    try:
      if event["amount"] <= 0:
            raise ValueError("Payment amount must be positive.")
            successful.append(event)
    except (KeyError, ValueError) as e:
        dead_letter_queue.append({
            "event": event,
            "error": str(e)
        })
print("Account:", account)
print("Successful payments:", successful)
print("Dead-letter queue:", dead_letter_queue)
# Out:
# Account: ACC-1096
# Successful payments: []
# Dead-letter queue: [{'event': {'id': 'P102', 'amount': -200}, 'error': 'Payment amount must be positive.'}]

# %% [markdown]
# ### Q97. Make batch settlement failure-isolated for banking case 3; use sample reference `ACC-1097` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1097"
settlements = [
    {"id": "S101", "amount": 1200},
    {"id": "S102", "amount": -300},
    {"id": "S103", "amount": 1800}
]
successful = []
failed = []
for settlement in settlements:
    try:
        if settlement["amount"] <= 0:
            raise ValueError("Settlement amount must be positive.")
            successful.append(settlement)
    except ValueError as e:
        failed.append({
            "id": settlement["id"],
            "reason": str(e)
        })
print("Account:", account)
print("Successful settlements:", successful)
print("Failed settlements:", failed)
# Out:
# Account: ACC-1097
# Successful settlements: []
# Failed settlements: [{'id': 'S102', 'reason': 'Settlement amount must be positive.'}]

# %% [markdown]
# ### Q98. Report exact paths in nested statements for banking case 3; use sample reference `ACC-1098` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1098"
customer = {
    "profile": {
        "address": {
            "city": "Bangalore"
        }
    }
}

try:
    pin_code = customer["profile"]["address"]["pin_code"]
except KeyError as e:
    print("Account:", account)
    print(
        "Missing path: customer -> profile -> address ->",
        e
    )
# Out:
# Account: ACC-1098
# Missing path: customer -> profile -> address -> 'pin_code'

# %% [markdown]
# ### Q99. Design idempotent recovery after timeout for banking case 3; use sample reference `ACC-1099` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1099"
transaction_id = "TXN-1099"
amount = 1500.00
processed_transactions = {
    "TXN-1099": 1500.00
}

try:
    if transaction_id in processed_transactions:
        print("Transaction already processed.")
        print("No duplicate debit performed.")

    else:
        processed_transactions[transaction_id] = amount
        print("Transaction processed successfully.")
except Exception as e:
    print("Recovery failed:", e)
print("Account:", account)
print("Processed transactions:", processed_transactions)
# Out:
# Transaction already processed.
# No duplicate debit performed.
# Account: ACC-1099
# Processed transactions: {'TXN-1099': 1500.0}

# %% [markdown]
# ### Q100. Build an exception-safe reconciliation pipeline for banking case 3; use sample reference `ACC-1100` and explain the result.
#
# **Hints**
#
# 1. Identify the smallest risky statement and the narrow exception it can raise.
# 2. Keep business-rule failures distinct from programming or infrastructure failures.
# 3. For medium/difficult work, preserve the original cause and protect partially updated balances.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
account = "ACC-1100"
bank_records = [
    {"id": "T101", "amount": 1000},
    {"id": "T102", "amount": 2000},
    {"id": "T103", "amount": -400}
]
ledger_total = 3000
successful = []
failed = []
for record in bank_records:
    try:
        amount = record["amount"]
        if amount <= 0:
            raise ValueError("Invalid transaction amount.")
            successful.append(record)
    except (KeyError, ValueError) as e:
        failed.append({
            "id": record.get("id", "UNKNOWN"),
            "error": str(e)
        })
bank_total = sum(
    record["amount"] for record in successful
)
print("Account:", account)
print("Bank total:", bank_total)
print("Ledger total:", ledger_total)
if bank_total == ledger_total:
    print("Reconciliation successful.")
else:
    print("Reconciliation mismatch.")
print("Failed records:", failed)
# Out:
# Account: ACC-1100
# Bank total: 0
# Ledger total: 3000
# Reconciliation mismatch.
# Failed records: [{'id': 'T103', 'error': 'Invalid transaction amount.'}]
